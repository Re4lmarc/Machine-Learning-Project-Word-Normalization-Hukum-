# %% [markdown]
# <a href="https://colab.research.google.com/github/Re4lmarc/Machine-Learning-Project-Word-Normalization-Hukum-/blob/master/Normalisasi%20Bahasa%20Indonesia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mounting Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/My\ Drive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive

# %% [markdown]
# ## Part Drive Refly

# %%
cd Project ML/
# Out:
# /content/drive/My Drive/Project ML

# %% [markdown]
# ## Part drive Adrian

# %%
# %cd Colab\ Notebooks
# Out:
# [Errno 2] No such file or directory: 'Colab Notebooks'
# /content/drive/My Drive/Project ML

# %%
# %cd data
# Out:
# [Errno 2] No such file or directory: 'data'
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# # Part Utama

# %% [markdown]
# ## Instalasi yang dibutuhkan

# %%
pip install --upgrade gensim
# Out:
# Requirement already up-to-date: gensim in /usr/local/lib/python3.6/dist-packages (3.8.3)
# Requirement already satisfied, skipping upgrade: six>=1.5.0 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.12.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.3 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.18.4)
# Requirement already satisfied, skipping upgrade: scipy>=0.18.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (1.4.1)
# Requirement already satisfied, skipping upgrade: smart-open>=1.8.1 in /usr/local/lib/python3.6/dist-packages (from gensim) (2.0.0)
# Requirement already satisfied, skipping upgrade: boto3 in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (1.13.13)
# Requirement already satisfied, skipping upgrade: boto in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (2.49.0)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.6/dist-packages (from smart-open>=1.8.1->gensim) (2.23.0)
# Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim) (0.10.0)
# Requirement already satisfied, skipping upgrade: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim) (0.3.3)
# Requirement already satisfied, skipping upgrade: botocore<1.17.0,>=1.16.13 in /usr/local/lib/python3.6/dist-packages (from boto3->smart-open>=1.8.1->gensim) (1.16.13)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (2020.4.5.1)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (1.24.3)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->smart-open>=1.8.1->gensim) (2.9)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.6/dist-packages (from botocore<1.17.0,>=1.16.13->boto3->smart-open>=1.8.1->gensim) (2.8.1)
# Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.17.0,>=1.16.13->boto3->smart-open>=1.8.1->gensim) (0.15.2)

# %%
pip install category_encoders
# Out:
# Requirement already satisfied: category_encoders in /usr/local/lib/python3.6/dist-packages (2.2.2)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.10.2)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.18.4)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.23.1)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (0.5.1)
# Requirement already satisfied: pandas>=0.21.1 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.0.4)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.6/dist-packages (from category_encoders) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20.0->category_encoders) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn>=0.20.0->category_encoders) (0.15.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from patsy>=0.5.1->category_encoders) (1.12.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21.1->category_encoders) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.21.1->category_encoders) (2018.9)

# %% [markdown]
# ## Semua Library

# %%
# Importing Required Libraries
import category_encoders as ce
import pandas as pd
import sqlite3 as sql
import re
import nltk
import glob
import numpy as np
import string
import logging as log
import os
import csv
import pickle
from sklearn import preprocessing
from gensim.models import FastText
from gensim import utils
from gensim.test.utils import datapath
from gensim.utils import tokenize
from string import punctuation
from nltk.tokenize import word_tokenize, RegexpTokenizer
from sqlite3 import Error
from tqdm.autonotebook import tqdm
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report, confusion_matrix

# %% [markdown]
# ## Connect Database

# %%
conn = sql.connect("/content/drive/My Drive/Project ML/DBnews.db")
dataset = pd.read_sql_query("SELECT * FROM t_comments", conn)

# %%
con2 = sql.connect("/content/drive/My Drive/Project ML/korpus.db")
df_korpus_kata = pd.read_sql_query("SELECT * from korpus_kata", con2)
df_korpus_kalimat = pd.read_sql_query("SELECT * from korpus_kalimat", con2)

# %%
dataset['comment'].value_counts()
# Out:
# #2019GantiPresiden                                                                              140
# Alhamdulillah                                                                                   130
# #2019gantipresiden                                                                              108
# %u2063#2019PrabowoPresiden                                                                       84
# mantap                                                                                           61
#                                                                                                ...
# Pejabat negara jangan memberi contoh tidak baik kepada rakyat dengan tidak menghormati hukum      1
# Ijtimak ulama, tapi kok yg hadir banyak orang politik dan bicara capres....?�                     1
# Selama anggarannya ada. Zaman now apa masih ada ya anggaran THR buat ormas2 seperti ini ?         1
# kita bersuara disini percuma kl ya? g ngaruh jg..g bkl jg dirubah aturannya                       1
# Iyalah... 176-761.... %uD83D%uDE02%uD83D%uDE02                                                    1
# Name: comment, Length: 584385, dtype: int64

# %% [markdown]
# ## Semua Proses Editing

# %%
list_vocab_kalimat = list(df_korpus_kalimat['kalimat'])

# %%
for idx_list in range(len(list_vocab_kalimat)):
  list_vocab_kalimat[idx_list] = re.sub('<s>', '', list_vocab_kalimat[idx_list]) 
  list_vocab_kalimat[idx_list] = re.sub('</s>', '', list_vocab_kalimat[idx_list])

# %%
list_vocab_kalimat[0] = list_vocab_kalimat[0][1:len(list_vocab_kalimat[0])]
list_vocab_kalimat[0]
# Out:
# 'penjelasan umum'

# %%
kamus_kata_banyak =  open('/content/drive/My Drive/Project ML/ind-id_web_2017_1M/ind-id_web_2017_1M-sentences.txt', encoding='utf-8')
semua_line = kamus_kata_banyak.readlines()

# %%
for i in range(len(semua_line)):
  semua_line[i] = a = re.split('\n|\t',semua_line[i])
  semua_line[i] = semua_line[i][1:len(semua_line[i])-1]
  semua_line[i] = semua_line[i][0]

# %%
all_comments = list(dataset['comment'])

# %%
semua_kalimat_fasttext = semua_line + all_comments + list_vocab_kalimat

# %%
numbers = re.compile(r'[0-9]')
def number(teks):
    teks = [numbers.sub("", word) for word in teks]
    teks = [word for word in teks if len(word) != 0]
    return teks

cleaning = RegexpTokenizer(r'\w+')
def clean(kalimat):
    kata_cleaning = cleaning.tokenize(kalimat)
    return kata_cleaning

def tokenize(kalimat):
    kata_tokenize = word_tokenize(kalimat)
    return kata_tokenize

def case_fold(kalimat):
    kata_lower = []
    for item in kalimat:
        kata_lower.append(str(item).lower())
    return kata_lower

# %%
all_filter_fasttext = []
for idx_fasttext in range(len(semua_kalimat_fasttext)):
    token_comments = clean(semua_kalimat_fasttext[idx_fasttext])
    token_comments = number(token_comments)
    token_comments = case_fold(token_comments)
    all_filter_fasttext.append(token_comments)

# %%
all_filter_comments = []
for idx_comments in range(len(all_comments)):
    token_comments = clean(all_comments[idx_comments])
    token_comments = number(token_comments)
    token_comments = case_fold(token_comments)
    all_filter_comments.append(token_comments)

# %% [markdown]
# ## Filter Kata Non KBBI Fase 1

# %% [markdown]
# ### Filter Kata Baku dengan predefined Corpus

# %%
df_korpus_kata = df_korpus_kata.dropna(subset=['kata'], axis=0)
list_vocab_kata = list(df_korpus_kata['kata'])
list_vocab_kalimat = list(df_korpus_kalimat['kalimat'])
list_tag_kata = list(df_korpus_kata['tag'])

# %%
not_kbbi = []

dictionary_kata = {}

for kalimat in all_filter_comments:
 for kata in kalimat:
    if kata in list_vocab_kata:
      dictionary_kata[kata] = kata
    else:
      not_kbbi.append(kata)

# %% [markdown]
# ### Save Kata Baku dan tidak baku yang terfilter

# %%
df_dictionary_kata.columns = ['Kata Sebelum', 'Kata KBBI'] 
df_dictionary_kata
df_dictionary_kata.to_csv('Map Kata KBBI.csv',index=False)

# %%
for idx_list in range(len(list_vocab_kalimat)):
  list_vocab_kalimat[idx_list] = re.sub('<s>', '', list_vocab_kalimat[idx_list]) 
  list_vocab_kalimat[idx_list] = re.sub('</s>', '', list_vocab_kalimat[idx_list])

# %%
kata_non_kbbi = pd.Series(not_kbbi)
kata_non_kbbi.head()
# Out:
# 0    wkwkwk
# 1       dpr
# 2    mantab
# 3        br
# 4        kl
# dtype: object

# %% [markdown]
# ### Load Kata KBBI dan Non KBBI

# %%
kata_non_kbbi = pd.read_csv('Map Kata Non KBBI.csv', index_col=[0])
kata_kbbi_pertama = pd.read_excel('Map Kata KBBI2.xlsx')
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/lib/arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
new_dictionary = dictionary_kata.copy()

for idx in range(len(new_dictionary))

# %%
kata_non_kbbi.columns = ['kata tidak baku']
list_kata_non_kbbi = list(kata_non_kbbi['kata tidak baku']) 
print(len(list_kata_non_kbbi))
# Out:
# 1967934

# %% [markdown]
# ## FastText

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ### Kamus Kata benar + dataset

# %%
tok_new[0:10]

# %%
model = FastText()

#build the vocabulary
model.build_vocab(sentences=tok_new)

# train the model
model.train(sentences=tok_new, epochs=model.epochs, total_examples=model.corpus_count, total_word=model.corpus_total_words)

print(model)
# Out:
# FastText(vocab=21655, size=100, alpha=0.025)

# %%
'makin' in model.wv.vocab
# Out:
# True

# %%
model.wv.similarity('makan', 'mkn')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# -0.40324718

# %%
model.wv.most_similar('makan')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# [('makanya', 0.9030953645706177),
#  ('makanlah', 0.8966188430786133),
#  ('makannya', 0.884308934211731),
#  ('dimakan', 0.8494226932525635),
#  ('termakan', 0.8285702466964722),
#  ('makanuntuk', 0.8195314407348633),
#  ('makam', 0.8078377842903137),
#  ('perlemakan', 0.8075428009033203),
#  ('disamakan', 0.807175874710083),
#  ('diutamakan', 0.8063433170318604)]

# %%
model_fasttext.wv.similarity('siapa', 'siape')
# Out:
# /usr/local/lib/python3.6/dist-packages/gensim/matutils.py:737: FutureWarning: Conversion of the second argument of issubdtype from `int` to `np.signedinteger` is deprecated. In future, it will be treated as `np.int64 == np.dtype(int).type`.
#   if np.issubdtype(vec.dtype, np.int):
# 0.75340754

# %% [markdown]
# ### Nama File

# %%
filename = 'fasttext_model_fixed.sav'
filename2 = 'fasttext_model_fixed_50.sav'
filename3 = 'fasttext_model_comment.sav'

# %% [markdown]
# #### Training & Saving Fasttext Model

# %%
model_fasttext = FastText(window=3, min_count=1)
model_fasttext.build_vocab(sentences=all_filter_comments)
total_examples = model_fasttext.corpus_count
model_fasttext.train(sentences=all_filter_comments, total_examples=total_examples, epochs=5)

# %%
pickle.dump(model_fasttext, open(filename3, 'wb'))

# %% [markdown]
# #### Melakukan Load Model Fasttext yang sudah di Train

# %%
# Model Fasttext untuk Kata Gabungan semua Corpus
fasttext_model_50 = pickle.load(open(filename2, 'rb'))

# Model Fasttext Untuk Kata Pada Comment
fasttext_model_comment = pickle.load(open(filename3, 'rb'))

# %%
print(fasttext_model_50)
print(fasttext_model_comment)
# Out:
# FastText(vocab=412721, size=50, alpha=0.025)
# FastText(vocab=172154, size=100, alpha=0.025)

# %% [markdown]
# ## Filter Kata Non KBBI Fase 2

# %%
df_datapairing = pd.read_csv('https://raw.githubusercontent.com/nasalsabila/kamus-alay/master/colloquial-indonesian-lexicon.csv')

# %%
slang_samadengan = df_datapairing['slang'] == 'mkn'
list(df_datapairing['formal'][slang_samadengan].head(1))[0]
# Out:
# 'makin'

# %%
kata_non_kbbi_dua = []
kata_non_formal = []
kata_formal = []
category_kata = []
vector_sebelum = []
vector_setelah = []

for idx in range(len(list_kata_non_kbbi)):
  slang_samadengan = df_datapairing['slang'] == list_kata_non_kbbi[idx]
  if not df_datapairing[slang_samadengan].empty:
    kata_non_formal.append(list_kata_non_kbbi[idx]) 
    kata_formal.append(list(df_datapairing['formal'][slang_samadengan].head(1))[0])
    category_kata.append(list(df_datapairing['category1'][slang_samadengan].head(1))[0])
    vector_sebelum.append(round(float(fasttext_model.wv[list_kata_non_kbbi[idx]]), 7))
    vector_setelah.append(round(float(fasttext_model.wv[df_datapairing['formal'][slang_samadengan].head(1)]), 7))
  else:
    kata_non_kbbi_dua.append(list_kata_non_kbbi[idx])

# %%
len(kata_formal)

df = pd.DataFrame(list(zip(kata_non_formal, kata_formal ,category_kata, vector_sebelum, vector_setelah)), columns =['Kata awal', 'Kata KBBI', 'Kategori', 'Vector Sebelum', 'Vector Setelah'])

# %%
slang_samadengan = df_datapairing['slang'] == 'br'
df_datapairing['formal'][slang_samadengan].head()
# Out:
# True

# %% [markdown]
# ### Fix Filter 2 Kesalahaan Input

# %%
df_kata_kbbi_2_fixed = pd.DataFrame({'Kata Awal' : list_kata_awal, 'Kata KBBI' : list_kata_kbbi, 'Kategori': list_kategori})
df_kata_kbbi_2_fixed.tail()
# Out:
#          Kata Awal   Kata KBBI          Kategori
# 674424     ngadain  mengadakan          afiksasi
# 674425     ngadain  mengadakan          afiksasi
# 674426       nulis     menulis          afiksasi
# 674427  sebenernya  sebenarnya  modifikasi vokal
# 674428       bener       benar  modifikasi vokal

# %%
df_kata_kbbi_2_fixed.to_csv('Map Kata KBBI 2_fixed.csv',index=False)

# %% [markdown]
# ### Load Hasil Filter 2

# %%
df_kata_kbbi_2_new = pd.read_csv('Map Kata KBBI 2_fixed.csv')

# %% [markdown]
# ## Filter kata Non KBBI fase 3

# %%
kata_non_kbbi = pd.Series(kata_non_kbbi_dua)
kata_non_kbbi.to_csv('Map Kata Non KBBI 2.csv',index=False)

# %%
# Melakukan clearning data dari Null Value dan Emotikon
df_kata_non_kbbi = pd.read_csv('Map Kata Non KBBI 2.csv')
df_kata_non_kbbi = df_kata_non_kbbi.dropna()
df_kata_non_kbbi = df_kata_non_kbbi[df_kata_non_kbbi['0'] != 'udd']

# %%
df_kata_non_kbbi.columns = ['Kata Sebelum']
df_kata_non_kbbi['Kata KBBI'] = 'none'

# %%
tuple_kata_jokowi = fasttext_model_comment.wv.most_similar('jokowi', topn=550)
first_tuple_jokowi = [a_tuple[0] for a_tuple in tuple_kata_jokowi if 'jokowi' in a_tuple[0] or 'joko' in a_tuple[0] or 'owi' in a_tuple[0] or 'jkw' in a_tuple[0]]

# %%
tuple_kata_ahok = fasttext_model_comment.wv.most_similar('ahok', topn=550)
first_tuple_ahok = [a_tuple[0] for a_tuple in tuple_kata_ahok if lcs(a_tuple[0], 'ahok', len(a_tuple[0]), 4) >= 3 and a_tuple[0] not in first_tuple_jokowi]

# %%
tuple_kata_prabowo = fasttext_model_comment.wv.most_similar('prabowo', topn=550)
first_tuple_prabowo = [a_tuple[0] for a_tuple in tuple_kata_prabowo if lcs(a_tuple[0], 'prabowo', len(a_tuple[0]), len('prabowo')) >= 4 and a_tuple[0] not in first_tuple_jokowi and a_tuple[0] not in first_tuple_ahok]

# %%
tuple_kata_nazar = fasttext_model_comment.wv.most_similar('nazar', topn=310)
first_tuple_nazar = [a_tuple[0] for a_tuple in tuple_kata_nazar if lcs(a_tuple[0], 'nazar', len(a_tuple[0]), len('nazar')) >= 4 and a_tuple[0] not in first_tuple_jokowi and a_tuple[0] not in first_tuple_ahok not in first_tuple_prabowo]

# %%
tuple_kata_djarot = fasttext_model_comment.wv.most_similar('djarot', topn=100)
first_tuple_djarot = [a_tuple[0] for a_tuple in tuple_kata_nazar if lcs(a_tuple[0], 'nazar', len(a_tuple[0]), len('djarot')) >= 4 and a_tuple[0] not in first_tuple_jokowi and a_tuple[0] not in first_tuple_ahok not in first_tuple_prabowo not in first_tuple_nazar]

# %%
tuple_kata_gantipresiden = fasttext_model_comment.wv.most_similar('gakgantipresiden', topn=100)

# %%
# Mencari Kata - Kata yang merupakan nama

cari_jokowi = df_kata_non_kbbi['Kata Sebelum'].str.contains('jokowi')
cari_jkw = df_kata_non_kbbi['Kata Sebelum'].str.contains('jkw')
cari_owi = df_kata_non_kbbi['Kata Sebelum'].str.contains('owi')
cari_prabowo = df_kata_non_kbbi['Kata Sebelum'].str.contains('prabowo')
cari_wowo = df_kata_non_kbbi['Kata Sebelum'].str.contains('wowo')
cari_ahok = df_kata_non_kbbi['Kata Sebelum'].str.contains('ahok')
cari_nazar = df_kata_non_kbbi['Kata Sebelum'].str.contains('nazar')
cari_haha = df_kata_non_kbbi['Kata Sebelum'].str.contains('haha')
cari_wkwk = df_kata_non_kbbi['Kata Sebelum'].str.contains('wkwk')
cari_tuh = df_kata_non_kbbi['Kata Sebelum'] == 'tuh'

# %%
df_kata_non_kbbi['Kata Sebelum'][cari_haha].value_counts().sum()
# Out:
# 20882

# %%
df_jokowi = df_kata_non_kbbi[cari_jokowi | cari_jkw | cari_owi]

# %%
df_vocab_kata_sebelum = df_kata_non_kbbi["Kata Sebelum"].value_counts()

# %%
df_vocab_kata_sebelum = df_vocab_kata_sebelum.to_frame()
df_vocab_kata_sebelum = df_vocab_kata_sebelum.reset_index()
df_vocab_kata_sebelum.columns = ["Kata Sebelum", "Count Kata"]

# %%
df_vocab_kata_sebelum["Count Kata"][df_vocab_kata_sebelum["Kata Sebelum"].isin(first_tuple_nazar+["nazar"])].sum()
# Out:
# 231

# %%
df_vocab_kata_sebelum[df_vocab_kata_sebelum["Count Kata"] == 1].head(30)

# %%
df_kata_non_kbbi['Kata KBBI'][cari_jkw | cari_jkw | cari_owi]

# %%
df_kata_non_kbbi['Kata KBBI'][cari_jokowi | cari_jkw| cari_owi] = 'jokowi'
df_kata_non_kbbi['Kata KBBI'][cari_prabowo | cari_wowo] = 'prabowo'
df_kata_non_kbbi['Kata KBBI'][cari_wkwk] = 'haha'
df_kata_non_kbbi['Kata KBBI'][cari_tuh] = 'itu'

# %%
df_kata_non_kbbi['Kata KBBI'].value_counts().head(10)
# Out:
# none       1147234
# jokowi       42373
# prabowo      27873
# haha         16642
# itu          12257
# Name: Kata KBBI, dtype: int64

# %% [markdown]
# ## LCS

# %%
def lcs(X, Y, m, n): 
  
    if m == 0 or n == 0: 
       return 0; 
    elif X[m-1] == Y[n-1]: 
       return 1 + lcs(X, Y, m-1, n-1); 
    else: 
       return max(lcs(X, Y, m, n-1), lcs(X, Y, m-1, n));

# %% [markdown]
# # Gabung Semua DataFrame

# %%
df_kata_kbbi_2_new.columns = ["Kata Sebelum", "Kata KBBI", "Kategori"]

# %%
frames = [kata_kbbi_pertama, df_kata_kbbi_2_new, df_kata_non_kbbi]
df_all = pd.concat(frames, ignore_index=True)

# %%
df_all = df_all.replace(np.nan, 'Tidak Tahu', regex=True)
df_all = df_all.replace('none', 'Tidak Tahu', regex=True)

# %%
df_all['Kata Sebelum'].value_counts().head(10)
# Out:
# ga         44399
# jokowi     35529
# prabowo    17946
# klo        15842
# sdh        15423
# jd         14955
# tdk        14417
# org        13209
# utk        12931
# tuh        12257
# Name: Kata Sebelum, dtype: int64

# %%
list_sebelum_all = list(df_all['Kata Sebelum'])
list_kbbi_all = list(df_all['Kata KBBI'])

# %%
df_category_sebelum = df_all["Kata Sebelum"].value_counts().to_frame()
df_category_sebelum = df_category_sebelum.reset_index()
list_df_category = list(df_category_sebelum["index"])
df_category_kbbi = df_all["Kata KBBI"].value_counts().to_frame()
df_category_kbbi = df_category_kbbi.reset_index()
list_df_category_kbbi = list(df_category_kbbi["index"])

# %%
df_category_sebelum.columns = ["Kata Sebelum", "Counts Sebelum"]
df_category_sebelum.head()

df_category_kbbi.columns = ["Kata KBBI", "Counts KBBI"]
df_category_kbbi.head()
# Out:
#     Kata KBBI  Counts KBBI
# 0  Tidak Tahu      1147236
# 1      enggak        76101
# 2      jokowi        42373
# 3     prabowo        27873
# 4       sudah        22165

# %%
le_kata_sebelum = preprocessing.LabelEncoder()
le_kata_kbbi = preprocessing.LabelEncoder()
le_kata_sebelum.fit(list_df_category)
le_kata_kbbi.fit(list_df_category_kbbi)
# Out:
# LabelEncoder()

# %% [markdown]
# ### Transform Kamus (Not used now)

# %%
# list_transformed_sebelum_vocab = le_kata_sebelum.transform(list_df_category)
# list_transformed_kbbi_vocab = le_kata_kbbi.transform(list_df_category_kbbi)

# %%
split_length = int(len(list_sebelum_all) / 2)

# %% [markdown]
# ### Transform Whole Dataset

# %%
list_transformed_sebelum = list(le_kata_sebelum.transform(list_sebelum_all[:split_length]))
list_transformed_sebelum_2 = list(le_kata_sebelum.transform(list_sebelum_all[split_length:]))
list_transformed_kbbi = list(le_kata_kbbi.transform(list_kbbi_all[:split_length]))
list_transformed_kbbi_2 = list(le_kata_kbbi.transform(list_kbbi_all[split_length:]))

# %%
list_transformed_sebelum[-10: -1]
# Out:
# [110753, 171793, 54886, 29245, 27223, 1843, 29245, 54174, 144875]

# %%
list_transformed_sebelum_join = list_transformed_sebelum+list_transformed_sebelum_2 
list_transformed_kbbi_join = list_transformed_kbbi+list_transformed_kbbi_2

# %%
dictionary_sebelum = dict(zip(list_df_category, list_transformed_sebelum))
dictionary_kbbi = dict(zip(list_df_category_kbbi, list_transformed_kbbi))

# %% [markdown]
# ## Coba Coba

# %%
df_tes = pd.DataFrame({"Kata Sebelum" : list_sebelum_all, "Kata KBBI" : list_kbbi_all, "Encoded Kata Sebelum" : list_transformed_sebelum_join, "Encoded Kata KBBI" : list_transformed_kbbi_join})

# %%
df_tes.to_csv('Map Kata Setelah Encode.csv',index=False)

# %% [markdown]
# ### Load CSV Setelah Encode

# %%
df_tes = pd.read_csv('Map Kata Setelah Encode.csv')

# %% [markdown]
# ### Mengecilkan Train data

# %%
df_train = df_tes[['Kata Sebelum', 'Kata KBBI' ,'Encoded Kata Sebelum', 'Encoded Kata KBBI']].drop_duplicates()
# num_class = df_train['Encoded Kata KBBI'].drop_duplicates()
# num_class = len(num_class)
# print(num_class)

df_train.reset_index(drop=True, inplace=True)

# %%
from sklearn.tree import DecisionTreeClassifier

X_train = df_train['Encoded Kata Sebelum']
y_train = df_train['Encoded Kata KBBI']
# model_logreg = LogisticRegression()
clf = DecisionTreeClassifier()

# %%
X_train = X_train[0:10000]
y_train = y_train[0:10000]

X_train = np.append(X_train, 64422)
y_train = np.append(y_train, 7862)
X_train = np.append(X_train, 169449)
y_train = np.append(y_train, 16462)
X_train = np.append(X_train, 17730)
y_train = np.append(y_train, 2695)

# %%
X_train = X_train[ :, np.newaxis]

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
y_pred_train = clf.predict(X_train)

# %%
y_pred_train[1:100]
# Out:
# array([18163, 14516, 18258,  8381,  8132,  1259,  9820,  4729,  7286,
#         3459, 21953, 18145,  3410, 20129, 21419, 10902,  2329, 10774,
#        17715,  2658,  6566, 14199, 15928, 10581,  3485,  1010, 12481,
#        18143, 19486,  8069,  7553,    66,  2931,  3651,  8408,   809,
#        10180, 16414, 20216, 10382,  1088,   203, 10946,  7129, 18733,
#        21375, 16767,  7588, 11255,  7823,  8129, 11512, 10343,  3672,
#        20784, 11062,  7893,  6756,  7529, 10443,  7143,  7528, 19389,
#        12846,  9297, 14689,  8087, 11252,  1682, 14417, 16364,  3071,
#        18020,  2286,  2683,   199,  1441, 19551, 13997,  3785, 15590,
#         8306, 15460,  9070, 12175,  5031, 11257,   930, 19516, 19151,
#        13862,  4955, 18406,  8058, 11010,  3954, 17776, 18948, 17940])

# %%
print("Tingkat Accuracy :",  accuracy_score(y_train, y_pred_train))
# print(confusion_matrix(y_train, y_pred_train))
# Out:
# Tingkat Accuracy : 0.9999000299910027

# %%
# print(classification_report(y_train, y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      1.00      0.67         1
#            1       1.00      1.00      1.00         1
#            2       1.00      1.00      1.00         1
#            4       1.00      1.00      1.00         1
#            6       1.00      1.00      1.00         1
#            7       1.00      1.00      1.00         1
#            8       1.00      1.00      1.00         1
#           10       1.00      1.00      1.00         1
#           11       1.00      1.00      1.00         1
#           14       1.00      1.00      1.00         1
#           15       1.00      1.00      1.00         1
#           16       1.00      1.00      1.00         1
#           17       1.00      1.00      1.00         1
#           21       1.00      1.00      1.00         1
#           23       1.00      1.00      1.00         1
#           27       1.00      1.00      1.00         1
#           34       1.00      1.00      1.00         1
#           36       1.00      1.00      1.00         1
#           38       1.00      1.00      1.00         1
#           39       1.00      1.00      1.00         1
#           43       1.00      1.00      1.00         1
#           48       1.00      1.00      1.00         1
#           49       1.00      1.00      1.00         1
#           53       1.00      1.00      1.00         1
#           58       1.00      1.00      1.00         1
#           59       1.00      1.00      1.00         1
#           60       1.00      1.00      1.00         1
#           63       1.00      1.00      1.00         1
#           66       1.00      1.00      1.00         1
#           67       1.00      1.00      1.00         1
#           69       1.00      1.00      1.00         1
#           72       1.00      1.00      1.00         1
#           73       1.00      1.00      1.00         1
#           76       1.00      1.00      1.00         1
#           77       1.00      1.00      1.00         1
#           80       1.00      1.00      1.00         1
#           84       1.00      1.00      1.00         1
#           88       1.00      1.00      1.00         1
#           89       1.00      1.00      1.00         1
#           90       1.00      1.00      1.00         1
#           94       1.00      1.00      1.00         1
#           99       1.00      1.00      1.00         1
#          100       1.00      1.00      1.00         1
#          102       1.00      1.00      1.00         1
#          107       1.00      1.00      1.00         1
#          108       1.00      1.00      1.00         1
#          114       1.00      1.00      1.00         1
#          117       1.00      1.00      1.00         1
#          119       1.00      1.00      1.00         1
#          122       1.00      1.00      1.00         1
#          124       1.00      1.00      1.00         1
#          136       1.00      1.00      1.00         1
#          145       1.00      1.00      1.00         1
#          148       1.00      1.00      1.00         1
#          149       1.00      1.00      1.00         1
#          151       1.00      1.00      1.00         1
#          154       1.00      1.00      1.00         1
#          155       1.00      1.00      1.00         1
#          156       1.00      1.00      1.00         1
#          157       1.00      1.00      1.00         1
#          159       1.00      1.00      1.00         1
#          160       1.00      1.00      1.00         1
#          161       1.00      1.00      1.00         1
#          162       1.00      1.00      1.00         1
#          163       1.00      1.00      1.00         1
#          165       1.00      1.00      1.00         1
#          168       1.00      1.00      1.00         1
#          169       1.00      1.00      1.00         1
#          176       1.00      1.00      1.00         1
#          177       1.00      1.00      1.00         1
#          178       1.00      1.00      1.00         1
#          179       1.00      1.00      1.00         1
#          182       1.00      1.00      1.00         1
#          183       1.00      1.00      1.00         1
#          185       1.00      1.00      1.00         1
#          187       1.00      1.00      1.00         1
#          188       1.00      1.00      1.00         1
#          191       1.00      1.00      1.00         1
#          193       1.00      1.00      1.00         1
#          194       1.00      1.00      1.00         1
#          197       1.00      1.00      1.00         1
#          199       1.00      1.00      1.00         1
#          201       1.00      1.00      1.00         1
#          203       1.00      1.00      1.00         1
#          204       1.00      1.00      1.00         1
#          205       1.00      1.00      1.00         1
#          206       1.00      1.00      1.00         1
#          207       1.00      1.00      1.00         1
#          208       1.00      1.00      1.00         1
#          210       1.00      1.00      1.00         1
#          212       1.00      1.00      1.00         1
#          217       1.00      1.00      1.00         1
#          222       1.00      1.00      1.00         1
#          223       1.00      1.00      1.00         1
#          225       1.00      1.00      1.00         1
#          226       1.00      1.00      1.00         1
#          227       1.00      1.00      1.00         1
#          228       1.00      1.00      1.00         1
#          229       1.00      1.00      1.00         1
#          230       1.00      1.00      1.00         1
#          231       1.00      1.00      1.00         1
#          234       1.00      1.00      1.00         1
#          236       1.00      1.00      1.00         1
#          237       1.00      1.00      1.00         1
#          238       1.00      1.00      1.00         1
#          239       1.00      1.00      1.00         1
#          240       1.00      1.00      1.00         1
#          241       1.00      1.00      1.00         1
#          242       1.00      1.00      1.00         1
#          244       1.00      1.00      1.00         1
#          246       1.00      1.00      1.00         1
#          247       1.00      1.00      1.00         1
#          249       1.00      1.00      1.00         1
#          253       1.00      1.00      1.00         1
#          254       1.00      1.00      1.00         1
#          256       1.00      1.00      1.00         1
#          257       1.00      1.00      1.00         1
#          260       1.00      1.00      1.00         1
#          262       1.00      1.00      1.00         1
#          263       1.00      1.00      1.00         1
#          265       1.00      1.00      1.00         1
#          267       1.00      1.00      1.00         1
#          269       1.00      1.00      1.00         1
#          270       1.00      1.00      1.00         1
#          273       1.00      1.00      1.00         1
#          277       1.00      1.00      1.00         1
#          278       1.00      1.00      1.00         1
#          279       1.00      1.00      1.00         1
#          280       1.00      1.00      1.00         1
#          281       1.00      1.00      1.00         1
#          284       1.00      1.00      1.00         1
#          285       1.00      1.00      1.00         1
#          289       1.00      1.00      1.00         1
#          293       1.00      1.00      1.00         1
#          296       1.00      1.00      1.00         1
#          299       1.00      1.00      1.00         1
#          301       1.00      1.00      1.00         1
#          302       1.00      1.00      1.00         1
#          303       1.00      1.00      1.00         1
#          304       1.00      1.00      1.00         1
#          306       1.00      1.00      1.00         1
#          307       1.00      1.00      1.00         1
#          308       1.00      1.00      1.00         1
#          309       1.00      1.00      1.00         1
#          310       1.00      1.00      1.00         1
#          311       1.00      1.00      1.00         1
#          313       1.00      1.00      1.00         1
#          315       1.00      1.00      1.00         1
#          316       1.00      1.00      1.00         1
#          318       1.00      1.00      1.00         1
#          319       1.00      1.00      1.00         1
#          320       1.00      1.00      1.00         1
#          322       1.00      1.00      1.00         1
#          326       1.00      1.00      1.00         1
#          329       1.00      1.00      1.00         1
#          331       1.00      1.00      1.00         1
#          339       1.00      1.00      1.00         1
#          340       1.00      1.00      1.00         1
#          341       1.00      1.00      1.00         1
#          344       1.00      1.00      1.00         1
#          345       1.00      1.00      1.00         1
#          348       1.00      1.00      1.00         1
#          350       1.00      1.00      1.00         1
#          353       1.00      1.00      1.00         1
#          354       1.00      1.00      1.00         1
#          355       1.00      1.00      1.00         1
#          359       1.00      1.00      1.00         1
#          362       1.00      1.00      1.00         1
#          363       1.00      1.00      1.00         1
#          366       1.00      1.00      1.00         1
#          376       1.00      1.00      1.00         1
#          380       1.00      1.00      1.00         1
#          381       1.00      1.00      1.00         1
#          382       1.00      1.00      1.00         1
#          383       1.00      1.00      1.00         1
#          384       1.00      1.00      1.00         1
#          385       1.00      1.00      1.00         1
#          389       1.00      1.00      1.00         1
#          390       1.00      1.00      1.00         1
#          394       1.00      1.00      1.00         1
#          395       1.00      1.00      1.00         1
#          398       1.00      1.00      1.00         1
#          399       1.00      1.00      1.00         1
#          400       1.00      1.00      1.00         1
#          401       1.00      1.00      1.00         1
#          403       1.00      1.00      1.00         1
#          404       1.00      1.00      1.00         1
#          405       1.00      1.00      1.00         1
#          406       1.00      1.00      1.00         1
#          409       1.00      1.00      1.00         1
#          410       1.00      1.00      1.00         1
#          413       1.00      1.00      1.00         1
#          416       1.00      1.00      1.00         1
#          417       1.00      1.00      1.00         1
#          420       1.00      1.00      1.00         1
#          422       1.00      1.00      1.00         1
#          430       1.00      1.00      1.00         1
#          432       1.00      1.00      1.00         1
#          436       1.00      1.00      1.00         1
#          437       1.00      1.00      1.00         1
#          438       1.00      1.00      1.00         1
#          442       1.00      1.00      1.00         1
#          445       1.00      1.00      1.00         1
#          447       1.00      1.00      1.00         1
#          448       1.00      1.00      1.00         1
#          449       1.00      1.00      1.00         1
#          452       1.00      1.00      1.00         1
#          455       1.00      1.00      1.00         1
#          457       1.00      1.00      1.00         1
#          459       1.00      1.00      1.00         1
#          461       1.00      1.00      1.00         1
#          463       1.00      1.00      1.00         1
#          467       1.00      1.00      1.00         1
#          468       1.00      1.00      1.00         1
#          469       1.00      1.00      1.00         1
#          470       1.00      1.00      1.00         1
#          471       1.00      1.00      1.00         1
#          479       1.00      1.00      1.00         1
#          481       1.00      1.00      1.00         1
#          488       1.00      1.00      1.00         1
#          491       1.00      1.00      1.00         1
#          492       1.00      1.00      1.00         1
#          493       1.00      1.00      1.00         1
#          494       1.00      1.00      1.00         1
#          498       1.00      1.00      1.00         1
#          499       1.00      1.00      1.00         1
#          500       1.00      1.00      1.00         1
#          502       1.00      1.00      1.00         1
#          505       1.00      1.00      1.00         1
#          506       1.00      1.00      1.00         1
#          507       1.00      1.00      1.00         1
#          509       1.00      1.00      1.00         1
#          510       1.00      1.00      1.00         1
#          513       1.00      1.00      1.00         1
#          516       1.00      1.00      1.00         1
#          518       1.00      1.00      1.00         1
#          519       1.00      1.00      1.00         1
#          521       1.00      1.00      1.00         1
#          523       1.00      1.00      1.00         1
#          527       1.00      1.00      1.00         1
#          528       1.00      1.00      1.00         1
#          529       1.00      1.00      1.00         1
#          530       1.00      1.00      1.00         1
#          531       1.00      1.00      1.00         1
#          533       1.00      1.00      1.00         1
#          534       1.00      1.00      1.00         1
#          535       1.00      1.00      1.00         1
#          539       1.00      1.00      1.00         1
#          540       1.00      1.00      1.00         1
#          541       1.00      1.00      1.00         1
#          544       1.00      1.00      1.00         1
#          545       1.00      1.00      1.00         1
#          546       1.00      1.00      1.00         1
#          548       1.00      1.00      1.00         1
#          549       1.00      1.00      1.00         1
#          550       1.00      1.00      1.00         1
#          551       1.00      1.00      1.00         1
#          555       1.00      1.00      1.00         1
#          561       1.00      1.00      1.00         1
#          562       1.00      1.00      1.00         1
#          565       1.00      1.00      1.00         1
#          567       1.00      1.00      1.00         1
#          568       1.00      1.00      1.00         1
#          574       1.00      1.00      1.00         1
#          576       1.00      1.00      1.00         1
#          577       1.00      1.00      1.00         1
#          578       1.00      1.00      1.00         1
#          579       1.00      1.00      1.00         1
#          580       1.00      1.00      1.00         1
#          581       1.00      1.00      1.00         1
#          584       1.00      1.00      1.00         1
#          585       1.00      1.00      1.00         1
#          589       1.00      1.00      1.00         1
#          590       1.00      1.00      1.00         1
#          591       1.00      1.00      1.00         1
#          595       1.00      1.00      1.00         1
#          596       1.00      1.00      1.00         1
#          599       1.00      1.00      1.00         1
#          600       1.00      1.00      1.00         1
#          601       1.00      1.00      1.00         1
#          602       1.00      1.00      1.00         1
#          603       1.00      1.00      1.00         1
#          607       1.00      1.00      1.00         1
#          613       1.00      1.00      1.00         1
#          614       1.00      1.00      1.00         1
#          615       1.00      1.00      1.00         1
#          616       1.00      1.00      1.00         1
#          617       1.00      1.00      1.00         1
#          618       1.00      1.00      1.00         1
#          624       1.00      1.00      1.00         1
#          628       1.00      1.00      1.00         1
#          630       1.00      1.00      1.00         1
#          631       1.00      1.00      1.00         1
#          632       1.00      1.00      1.00         1
#          634       1.00      1.00      1.00         1
#          635       1.00      1.00      1.00         1
#          643       1.00      1.00      1.00         1
#          645       1.00      1.00      1.00         1
#          648       1.00      1.00      1.00         1
#          649       1.00      1.00      1.00         1
#          654       1.00      1.00      1.00         1
#          660       1.00      1.00      1.00         1
#          661       1.00      1.00      1.00         1
#          665       1.00      1.00      1.00         1
#          667       1.00      1.00      1.00         1
#          668       1.00      1.00      1.00         1
#          672       1.00      1.00      1.00         1
#          673       1.00      1.00      1.00         1
#          678       1.00      1.00      1.00         1
#          679       1.00      1.00      1.00         1
#          681       1.00      1.00      1.00         1
#          683       1.00      1.00      1.00         1
#          685       1.00      1.00      1.00         1
#          686       1.00      1.00      1.00         1
#          688       1.00      1.00      1.00         1
#          690       1.00      1.00      1.00         1
#          692       1.00      1.00      1.00         1
#          693       1.00      1.00      1.00         1
#          694       1.00      1.00      1.00         1
#          698       1.00      1.00      1.00         1
#          699       1.00      1.00      1.00         1
#          700       1.00      1.00      1.00         1
#          702       1.00      1.00      1.00         1
#          703       1.00      1.00      1.00         1
#          704       1.00      1.00      1.00         1
#          705       1.00      1.00      1.00         1
#          709       1.00      1.00      1.00         1
#          720       1.00      1.00      1.00         1
#          722       1.00      1.00      1.00         1
#          724       1.00      1.00      1.00         1
#          726       1.00      1.00      1.00         1
#          728       1.00      1.00      1.00         1
#          729       1.00      1.00      1.00         1
#          731       1.00      1.00      1.00         1
#          732       1.00      1.00      1.00         1
#          733       1.00      1.00      1.00         1
#          734       1.00      1.00      1.00         1
#          735       1.00      1.00      1.00         1
#          736       1.00      1.00      1.00         1
#          737       1.00      1.00      1.00         1
#          743       1.00      1.00      1.00         1
#          744       1.00      1.00      1.00         1
#          746       1.00      1.00      1.00         1
#          747       1.00      1.00      1.00         1
#          748       1.00      1.00      1.00         1
#          751       1.00      1.00      1.00         1
#          752       1.00      1.00      1.00         1
#          754       1.00      1.00      1.00         1
#          756       1.00      1.00      1.00         1
#          757       1.00      1.00      1.00         1
#          758       1.00      1.00      1.00         1
#          764       1.00      1.00      1.00         1
#          767       1.00      1.00      1.00         1
#          771       1.00      1.00      1.00         1
#          773       1.00      1.00      1.00         1
#          774       1.00      1.00      1.00         1
#          775       1.00      1.00      1.00         1
#          780       1.00      1.00      1.00         1
#          782       1.00      1.00      1.00         1
#          785       1.00      1.00      1.00         1
#          787       1.00      1.00      1.00         1
#          790       1.00      1.00      1.00         1
#          791       1.00      1.00      1.00         1
#          793       1.00      1.00      1.00         1
#          794       1.00      1.00      1.00         1
#          796       1.00      1.00      1.00         1
#          799       1.00      1.00      1.00         1
#          800       1.00      1.00      1.00         1
#          801       1.00      1.00      1.00         1
#          804       1.00      1.00      1.00         1
#          805       1.00      1.00      1.00         1
#          807       1.00      1.00      1.00         1
#          809       1.00      1.00      1.00         1
#          811       1.00      1.00      1.00         1
#          812       1.00      1.00      1.00         1
#          813       1.00      1.00      1.00         1
#          814       1.00      1.00      1.00         1
#          816       1.00      1.00      1.00         1
#          817       1.00      1.00      1.00         1
#          819       1.00      1.00      1.00         1
#          820       1.00      1.00      1.00         1
#          821       1.00      1.00      1.00         1
#          823       1.00      1.00      1.00         1
#          824       1.00      1.00      1.00         1
#          827       1.00      1.00      1.00         1
#          828       1.00      1.00      1.00         1
#          830       1.00      1.00      1.00         1
#          836       1.00      1.00      1.00         1
#          838       1.00      1.00      1.00         1
#          840       1.00      1.00      1.00         1
#          841       1.00      1.00      1.00         1
#          842       1.00      1.00      1.00         1
#          844       1.00      1.00      1.00         1
#          848       1.00      1.00      1.00         1
#          849       1.00      1.00      1.00         1
#          851       1.00      1.00      1.00         1
#          852       1.00      1.00      1.00         1
#          859       1.00      1.00      1.00         1
#          860       1.00      1.00      1.00         1
#          875       1.00      1.00      1.00         1
#          878       1.00      1.00      1.00         1
#          881       1.00      1.00      1.00         1
#          883       1.00      1.00      1.00         1
#          884       1.00      1.00      1.00         1
#          885       1.00      1.00      1.00         1
#          887       1.00      1.00      1.00         1
#          888       1.00      1.00      1.00         1
#          889       1.00      1.00      1.00         1
#          890       1.00      1.00      1.00         1
#          891       1.00      1.00      1.00         1
#          895       1.00      1.00      1.00         1
#          896       1.00      1.00      1.00         1
#          897       1.00      1.00      1.00         1
#          900       1.00      1.00      1.00         1
#          902       1.00      1.00      1.00         1
#          906       1.00      1.00      1.00         1
#          909       1.00      1.00      1.00         1
#          913       1.00      1.00      1.00         1
#          918       1.00      1.00      1.00         1
#          919       1.00      1.00      1.00         1
#          920       1.00      1.00      1.00         1
#          923       1.00      1.00      1.00         1
#          926       1.00      1.00      1.00         1
#          930       1.00      1.00      1.00         1
#          933       1.00      1.00      1.00         1
#          934       1.00      1.00      1.00         1
#          936       1.00      1.00      1.00         1
#          938       1.00      1.00      1.00         1
#          941       1.00      1.00      1.00         1
#          944       1.00      1.00      1.00         1
#          955       1.00      1.00      1.00         1
#          956       1.00      1.00      1.00         1
#          958       1.00      1.00      1.00         1
#          959       1.00      1.00      1.00         1
#          960       1.00      1.00      1.00         1
#          961       1.00      1.00      1.00         1
#          962       1.00      1.00      1.00         1
#          963       1.00      1.00      1.00         1
#          966       1.00      1.00      1.00         1
#          967       1.00      1.00      1.00         1
#          968       1.00      1.00      1.00         1
#          969       1.00      1.00      1.00         1
#          974       1.00      1.00      1.00         1
#          975       1.00      1.00      1.00         1
#          976       1.00      1.00      1.00         1
#          978       1.00      1.00      1.00         1
#          979       1.00      1.00      1.00         1
#          981       1.00      1.00      1.00         1
#          983       1.00      1.00      1.00         1
#          984       1.00      1.00      1.00         1
#          985       1.00      1.00      1.00         1
#          986       1.00      1.00      1.00         1
#          987       1.00      1.00      1.00         1
#          990       1.00      1.00      1.00         1
#          991       1.00      1.00      1.00         1
#          992       1.00      1.00      1.00         1
#          993       1.00      1.00      1.00         1
#          994       1.00      1.00      1.00         1
#          995       1.00      1.00      1.00         1
#          997       1.00      1.00      1.00         1
#          999       1.00      1.00      1.00         1
#         1000       1.00      1.00      1.00         1
#         1001       1.00      1.00      1.00         1
#         1002       1.00      1.00      1.00         1
#         1003       1.00      1.00      1.00         1
#         1005       1.00      1.00      1.00         1
#         1007       1.00      1.00      1.00         1
#         1009       1.00      1.00      1.00         1
#         1010       1.00      1.00      1.00         1
#         1011       1.00      1.00      1.00         1
#         1014       1.00      1.00      1.00         1
#         1015       1.00      1.00      1.00         1
#         1020       1.00      1.00      1.00         1
#         1023       1.00      1.00      1.00         1
#         1025       1.00      1.00      1.00         1
#         1026       1.00      1.00      1.00         1
#         1027       1.00      1.00      1.00         1
#         1031       1.00      1.00      1.00         1
#         1033       1.00      1.00      1.00         1
#         1038       1.00      1.00      1.00         1
#         1039       1.00      1.00      1.00         1
#         1040       1.00      1.00      1.00         1
#         1042       1.00      1.00      1.00         1
#         1044       1.00      1.00      1.00         1
#         1051       1.00      1.00      1.00         1
#         1054       1.00      1.00      1.00         1
#         1055       1.00      1.00      1.00         1
#         1056       1.00      1.00      1.00         1
#         1059       1.00      1.00      1.00         1
#         1060       1.00      1.00      1.00         1
#         1061       1.00      1.00      1.00         1
#         1062       1.00      1.00      1.00         1
#         1063       1.00      1.00      1.00         1
#         1065       1.00      1.00      1.00         1
#         1068       1.00      1.00      1.00         1
#         1071       1.00      1.00      1.00         1
#         1073       1.00      1.00      1.00         1
#         1074       1.00      1.00      1.00         2
#         1075       1.00      1.00      1.00         1
#         1076       1.00      1.00      1.00         1
#         1077       1.00      1.00      1.00         1
#         1078       1.00      1.00      1.00         1
#         1080       1.00      1.00      1.00         1
#         1081       1.00      1.00      1.00         1
#         1083       1.00      1.00      1.00         1
#         1084       1.00      1.00      1.00         1
#         1085       1.00      1.00      1.00         1
#         1088       1.00      1.00      1.00         1
#         1089       1.00      1.00      1.00         1
#         1090       1.00      1.00      1.00         1
#         1091       1.00      1.00      1.00         1
#         1093       1.00      1.00      1.00         1
#         1095       1.00      1.00      1.00         1
#         1096       1.00      1.00      1.00         1
#         1099       1.00      1.00      1.00         1
#         1101       1.00      1.00      1.00         1
#         1103       1.00      1.00      1.00         1
#         1106       1.00      1.00      1.00         1
#         1107       1.00      1.00      1.00         1
#         1108       1.00      1.00      1.00         1
#         1109       1.00      1.00      1.00         1
#         1111       1.00      1.00      1.00         1
#         1114       1.00      1.00      1.00         1
#         1115       1.00      1.00      1.00         1
#         1116       1.00      1.00      1.00         1
#         1117       1.00      1.00      1.00         1
#         1119       1.00      1.00      1.00         1
#         1125       1.00      1.00      1.00         1
#         1126       1.00      1.00      1.00         1
#         1127       1.00      1.00      1.00         1
#         1130       1.00      1.00      1.00         1
#         1131       1.00      1.00      1.00         1
#         1132       1.00      1.00      1.00         1
#         1134       1.00      1.00      1.00         1
#         1138       1.00      1.00      1.00         1
#         1139       1.00      1.00      1.00         1
#         1144       1.00      1.00      1.00         1
#         1146       1.00      1.00      1.00         1
#         1147       1.00      1.00      1.00         1
#         1148       1.00      1.00      1.00         1
#         1152       1.00      1.00      1.00         1
#         1154       1.00      1.00      1.00         1
#         1155       1.00      1.00      1.00         1
#         1157       1.00      1.00      1.00         1
#         1158       1.00      1.00      1.00         1
#         1160       1.00      1.00      1.00         1
#         1164       1.00      1.00      1.00         1
#         1165       1.00      1.00      1.00         1
#         1170       1.00      1.00      1.00         1
#         1172       1.00      1.00      1.00         1
#         1174       1.00      1.00      1.00         1
#         1175       1.00      1.00      1.00         1
#         1179       1.00      1.00      1.00         1
#         1180       1.00      1.00      1.00         1
#         1184       1.00      1.00      1.00         1
#         1185       1.00      1.00      1.00         1
#         1186       1.00      1.00      1.00         1
#         1188       1.00      1.00      1.00         1
#         1189       1.00      1.00      1.00         1
#         1191       1.00      1.00      1.00         1
#         1196       1.00      1.00      1.00         1
#         1197       1.00      1.00      1.00         1
#         1201       1.00      1.00      1.00         1
#         1202       1.00      1.00      1.00         1
#         1203       1.00      1.00      1.00         1
#         1204       1.00      1.00      1.00         1
#         1206       1.00      1.00      1.00         1
#         1207       1.00      1.00      1.00         1
#         1210       1.00      1.00      1.00         1
#         1211       1.00      1.00      1.00         1
#         1212       1.00      1.00      1.00         1
#         1215       1.00      1.00      1.00         1
#         1216       1.00      1.00      1.00         1
#         1217       1.00      1.00      1.00         1
#         1218       1.00      1.00      1.00         1
#         1219       1.00      1.00      1.00         1
#         1220       1.00      1.00      1.00         1
#         1221       1.00      1.00      1.00         1
#         1226       1.00      1.00      1.00         1
#         1227       1.00      1.00      1.00         1
#         1228       1.00      1.00      1.00         1
#         1229       1.00      1.00      1.00         1
#         1232       1.00      1.00      1.00         1
#         1234       1.00      1.00      1.00         1
#         1236       1.00      1.00      1.00         1
#         1239       1.00      1.00      1.00         1
#         1241       1.00      1.00      1.00         1
#         1243       1.00      1.00      1.00         1
#         1244       1.00      1.00      1.00         1
#         1246       1.00      1.00      1.00         1
#         1247       1.00      1.00      1.00         1
#         1248       1.00      1.00      1.00         1
#         1250       1.00      1.00      1.00         1
#         1252       1.00      1.00      1.00         1
#         1253       1.00      1.00      1.00         1
#         1259       1.00      1.00      1.00         1
#         1260       1.00      1.00      1.00         1
#         1261       1.00      1.00      1.00         1
#         1266       1.00      1.00      1.00         1
#         1267       1.00      1.00      1.00         1
#         1268       1.00      1.00      1.00         1
#         1269       1.00      1.00      1.00         1
#         1273       1.00      1.00      1.00         1
#         1276       1.00      1.00      1.00         1
#         1277       1.00      1.00      1.00         1
#         1280       1.00      1.00      1.00         1
#         1282       1.00      1.00      1.00         1
#         1284       1.00      1.00      1.00         1
#         1287       1.00      1.00      1.00         1
#         1289       1.00      1.00      1.00         1
#         1291       1.00      1.00      1.00         1
#         1292       1.00      1.00      1.00         1
#         1293       1.00      1.00      1.00         1
#         1298       1.00      1.00      1.00         1
#         1303       1.00      1.00      1.00         1
#         1308       1.00      1.00      1.00         1
#         1309       1.00      1.00      1.00         1
#         1310       1.00      1.00      1.00         1
#         1311       1.00      1.00      1.00         1
#         1313       1.00      1.00      1.00         1
#         1315       1.00      1.00      1.00         1
#         1316       1.00      1.00      1.00         1
#         1317       1.00      1.00      1.00         1
#         1322       1.00      1.00      1.00         1
#         1323       1.00      1.00      1.00         1
#         1326       1.00      1.00      1.00         1
#         1327       1.00      1.00      1.00         1
#         1329       1.00      1.00      1.00         1
#         1330       1.00      1.00      1.00         1
#         1333       1.00      1.00      1.00         1
#         1334       1.00      1.00      1.00         1
#         1338       1.00      1.00      1.00         1
#         1341       1.00      1.00      1.00         1
#         1344       1.00      1.00      1.00         1
#         1345       1.00      1.00      1.00         1
#         1346       1.00      1.00      1.00         1
#         1347       1.00      1.00      1.00         1
#         1348       1.00      1.00      1.00         1
#         1349       1.00      1.00      1.00         1
#         1354       1.00      1.00      1.00         1
#         1355       1.00      1.00      1.00         1
#         1356       1.00      1.00      1.00         1
#         1358       1.00      1.00      1.00         1
#         1361       1.00      1.00      1.00         1
#         1362       1.00      1.00      1.00         1
#         1364       1.00      1.00      1.00         1
#         1366       1.00      1.00      1.00         1
#         1369       1.00      1.00      1.00         1
#         1371       1.00      1.00      1.00         1
#         1372       1.00      1.00      1.00         1
#         1373       1.00      1.00      1.00         1
#         1374       1.00      1.00      1.00         1
#         1377       1.00      1.00      1.00         1
#         1381       1.00      1.00      1.00         1
#         1383       1.00      1.00      1.00         1
#         1384       1.00      1.00      1.00         1
#         1386       1.00      1.00      1.00         1
#         1389       1.00      1.00      1.00         1
#         1390       1.00      1.00      1.00         1
#         1393       1.00      1.00      1.00         1
#         1395       1.00      1.00      1.00         1
#         1401       1.00      1.00      1.00         1
#         1403       1.00      1.00      1.00         1
#         1405       1.00      1.00      1.00         1
#         1407       1.00      1.00      1.00         1
#         1409       1.00      1.00      1.00         1
#         1412       1.00      1.00      1.00         1
#         1413       1.00      1.00      1.00         1
#         1416       1.00      1.00      1.00         1
#         1417       1.00      1.00      1.00         1
#         1421       1.00      1.00      1.00         1
#         1425       1.00      1.00      1.00         1
#         1429       1.00      1.00      1.00         1
#         1433       1.00      1.00      1.00         1
#         1435       1.00      1.00      1.00         1
#         1436       1.00      1.00      1.00         1
#         1439       1.00      1.00      1.00         1
#         1441       1.00      1.00      1.00         1
#         1444       1.00      1.00      1.00         1
#         1446       1.00      1.00      1.00         1
#         1447       1.00      1.00      1.00         1
#         1453       1.00      1.00      1.00         1
#         1454       1.00      1.00      1.00         1
#         1455       1.00      1.00      1.00         1
#         1456       1.00      1.00      1.00         1
#         1457       1.00      1.00      1.00         1
#         1460       1.00      1.00      1.00         1
#         1461       1.00      1.00      1.00         1
#         1464       1.00      1.00      1.00         1
#         1465       1.00      1.00      1.00         1
#         1466       1.00      1.00      1.00         1
#         1468       1.00      1.00      1.00         1
#         1474       1.00      1.00      1.00         1
#         1476       1.00      1.00      1.00         1
#         1480       1.00      1.00      1.00         1
#         1481       1.00      1.00      1.00         1
#         1485       1.00      1.00      1.00         1
#         1486       1.00      1.00      1.00         1
#         1488       1.00      1.00      1.00         1
#         1494       1.00      1.00      1.00         1
#         1496       1.00      1.00      1.00         1
#         1499       1.00      1.00      1.00         1
#         1500       1.00      1.00      1.00         1
#         1502       1.00      1.00      1.00         1
#         1503       1.00      1.00      1.00         1
#         1504       1.00      1.00      1.00         1
#         1505       1.00      1.00      1.00         1
#         1508       1.00      1.00      1.00         1
#         1509       1.00      1.00      1.00         1
#         1514       1.00      1.00      1.00         1
#         1518       1.00      1.00      1.00         1
#         1521       1.00      1.00      1.00         1
#         1527       1.00      1.00      1.00         1
#         1530       1.00      1.00      1.00         1
#         1531       1.00      1.00      1.00         1
#         1534       1.00      1.00      1.00         1
#         1537       1.00      1.00      1.00         1
#         1540       1.00      1.00      1.00         1
#         1545       1.00      1.00      1.00         1
#         1547       1.00      1.00      1.00         1
#         1548       1.00      1.00      1.00         1
#         1549       1.00      1.00      1.00         1
#         1550       1.00      1.00      1.00         1
#         1552       1.00      1.00      1.00         1
#         1553       1.00      1.00      1.00         1
#         1555       1.00      1.00      1.00         1
#         1556       1.00      1.00      1.00         1
#         1559       1.00      1.00      1.00         1
#         1561       1.00      1.00      1.00         1
#         1562       1.00      1.00      1.00         1
#         1564       1.00      1.00      1.00         1
#         1565       1.00      1.00      1.00         1
#         1569       1.00      1.00      1.00         1
#         1570       1.00      1.00      1.00         1
#         1571       1.00      1.00      1.00         1
#         1573       1.00      1.00      1.00         1
#         1574       1.00      1.00      1.00         1
#         1575       1.00      1.00      1.00         1
#         1576       1.00      1.00      1.00         1
#         1577       1.00      1.00      1.00         1
#         1579       1.00      1.00      1.00         1
#         1580       1.00      1.00      1.00         1
#         1582       1.00      1.00      1.00         1
#         1583       1.00      1.00      1.00         1
#         1586       1.00      1.00      1.00         1
#         1588       1.00      1.00      1.00         1
#         1594       1.00      1.00      1.00         1
#         1595       1.00      1.00      1.00         1
#         1596       1.00      1.00      1.00         1
#         1598       1.00      1.00      1.00         1
#         1602       1.00      1.00      1.00         1
#         1604       1.00      1.00      1.00         1
#         1607       1.00      1.00      1.00         1
#         1608       1.00      1.00      1.00         1
#         1609       1.00      1.00      1.00         1
#         1610       1.00      1.00      1.00         1
#         1611       1.00      1.00      1.00         1
#         1612       1.00      1.00      1.00         1
#         1616       1.00      1.00      1.00         1
#         1618       1.00      1.00      1.00         1
#         1622       1.00      1.00      1.00         1
#         1623       1.00      1.00      1.00         1
#         1624       1.00      1.00      1.00         1
#         1625       1.00      1.00      1.00         1
#         1627       1.00      1.00      1.00         1
#         1628       1.00      1.00      1.00         1
#         1632       1.00      1.00      1.00         1
#         1633       1.00      1.00      1.00         1
#         1634       1.00      1.00      1.00         1
#         1635       1.00      1.00      1.00         1
#         1637       1.00      1.00      1.00         1
#         1638       1.00      1.00      1.00         1
#         1639       1.00      1.00      1.00         1
#         1640       1.00      1.00      1.00         1
#         1643       1.00      1.00      1.00         1
#         1648       1.00      1.00      1.00         1
#         1650       1.00      1.00      1.00         1
#         1652       1.00      1.00      1.00         1
#         1653       1.00      1.00      1.00         1
#         1656       1.00      1.00      1.00         1
#         1659       1.00      1.00      1.00         1
#         1666       1.00      1.00      1.00         1
#         1667       1.00      1.00      1.00         1
#         1669       1.00      1.00      1.00         1
#         1670       1.00      1.00      1.00         1
#         1673       1.00      1.00      1.00         1
#         1675       1.00      1.00      1.00         1
#         1676       1.00      1.00      1.00         1
#         1678       1.00      1.00      1.00         1
#         1680       1.00      1.00      1.00         1
#         1682       1.00      1.00      1.00         1
#         1683       1.00      1.00      1.00         1
#         1684       1.00      1.00      1.00         1
#         1685       1.00      1.00      1.00         1
#         1686       1.00      1.00      1.00         1
#         1689       1.00      1.00      1.00         1
#         1691       1.00      1.00      1.00         1
#         1694       1.00      1.00      1.00         1
#         1697       1.00      1.00      1.00         1
#         1698       1.00      1.00      1.00         1
#         1699       1.00      1.00      1.00         1
#         1701       1.00      1.00      1.00         1
#         1702       1.00      1.00      1.00         1
#         1703       1.00      1.00      1.00         1
#         1704       1.00      1.00      1.00         1
#         1705       1.00      1.00      1.00         1
#         1709       1.00      1.00      1.00         1
#         1711       1.00      1.00      1.00         1
#         1714       1.00      1.00      1.00         1
#         1718       1.00      1.00      1.00         1
#         1720       1.00      1.00      1.00         1
#         1723       1.00      1.00      1.00         1
#         1724       1.00      1.00      1.00         1
#         1726       1.00      1.00      1.00         1
#         1729       1.00      1.00      1.00         1
#         1730       1.00      1.00      1.00         1
#         1731       1.00      1.00      1.00         1
#         1732       1.00      1.00      1.00         1
#         1733       1.00      1.00      1.00         1
#         1735       1.00      1.00      1.00         1
#         1736       1.00      1.00      1.00         1
#         1737       1.00      1.00      1.00         1
#         1739       1.00      1.00      1.00         1
#         1740       1.00      1.00      1.00         1
#         1744       1.00      1.00      1.00         1
#         1745       1.00      1.00      1.00         1
#         1746       1.00      1.00      1.00         1
#         1748       1.00      1.00      1.00         1
#         1752       1.00      1.00      1.00         1
#         1753       1.00      1.00      1.00         1
#         1754       1.00      1.00      1.00         1
#         1755       1.00      1.00      1.00         1
#         1756       1.00      1.00      1.00         1
#         1757       1.00      1.00      1.00         1
#         1758       1.00      1.00      1.00         1
#         1759       1.00      1.00      1.00         1
#         1761       1.00      1.00      1.00         1
#         1772       1.00      1.00      1.00         1
#         1773       1.00      1.00      1.00         1
#         1774       1.00      1.00      1.00         1
#         1775       1.00      1.00      1.00         1
#         1776       1.00      1.00      1.00         1
#         1777       1.00      1.00      1.00         1
#         1778       1.00      1.00      1.00         1
#         1779       1.00      1.00      1.00         1
#         1780       1.00      1.00      1.00         1
#         1781       1.00      1.00      1.00         1
#         1783       1.00      1.00      1.00         1
#         1785       1.00      1.00      1.00         1
#         1791       1.00      1.00      1.00         1
#         1794       1.00      1.00      1.00         1
#         1795       1.00      1.00      1.00         1
#         1799       1.00      1.00      1.00         1
#         1800       1.00      1.00      1.00         1
#         1801       1.00      1.00      1.00         1
#         1805       1.00      1.00      1.00         1
#         1808       1.00      1.00      1.00         1
#         1809       1.00      1.00      1.00         1
#         1810       1.00      1.00      1.00         1
#         1816       1.00      1.00      1.00         1
#         1818       1.00      1.00      1.00         1
#         1820       1.00      1.00      1.00         1
#         1821       1.00      1.00      1.00         1
#         1825       1.00      1.00      1.00         1
#         1827       1.00      1.00      1.00         1
#         1828       1.00      1.00      1.00         1
#         1830       1.00      1.00      1.00         1
#         1832       1.00      1.00      1.00         1
#         1838       1.00      1.00      1.00         1
#         1842       1.00      1.00      1.00         1
#         1843       1.00      1.00      1.00         1
#         1844       1.00      1.00      1.00         1
#         1845       1.00      1.00      1.00         1
#         1846       1.00      1.00      1.00         1
#         1847       1.00      1.00      1.00         1
#         1849       1.00      1.00      1.00         1
#         1850       1.00      1.00      1.00         1
#         1851       1.00      1.00      1.00         1
#         1852       1.00      1.00      1.00         1
#         1853       1.00      1.00      1.00         1
#         1854       1.00      1.00      1.00         1
#         1855       1.00      1.00      1.00         1
#         1856       1.00      1.00      1.00         1
#         1858       1.00      1.00      1.00         1
#         1859       1.00      1.00      1.00         1
#         1860       1.00      1.00      1.00         1
#         1862       1.00      1.00      1.00         1
# ...
#        21360       1.00      1.00      1.00         1
#        21364       1.00      1.00      1.00         1
#        21365       1.00      1.00      1.00         1
#        21366       1.00      1.00      1.00         1
#        21369       1.00      1.00      1.00         1
#        21370       1.00      1.00      1.00         1
#        21371       1.00      1.00      1.00         1
#        21373       1.00      1.00      1.00         1
#        21375       1.00      1.00      1.00         1
#        21376       1.00      1.00      1.00         1
#        21377       1.00      1.00      1.00         1
#        21378       1.00      1.00      1.00         1
#        21379       1.00      1.00      1.00         1
#        21381       1.00      1.00      1.00         1
#        21383       1.00      1.00      1.00         1
#        21387       1.00      1.00      1.00         1
#        21388       1.00      1.00      1.00         1
#        21391       1.00      1.00      1.00         1
#        21392       1.00      1.00      1.00         1
#        21398       1.00      1.00      1.00         1
#        21399       1.00      1.00      1.00         1
#        21400       1.00      1.00      1.00         1
#        21402       1.00      1.00      1.00         1
#        21403       1.00      1.00      1.00         1
#        21404       1.00      1.00      1.00         1
#        21406       1.00      1.00      1.00         1
#        21408       1.00      1.00      1.00         1
#        21409       1.00      1.00      1.00         1
#        21411       1.00      1.00      1.00         1
#        21413       1.00      1.00      1.00         1
#        21415       1.00      1.00      1.00         1
#        21416       1.00      1.00      1.00         1
#        21419       1.00      1.00      1.00         1
#        21420       1.00      1.00      1.00         1
#        21422       1.00      1.00      1.00         1
#        21423       1.00      1.00      1.00         1
#        21424       1.00      1.00      1.00         1
#        21427       1.00      1.00      1.00         1
#        21431       1.00      1.00      1.00         1
#        21433       1.00      1.00      1.00         1
#        21437       1.00      1.00      1.00         1
#        21438       1.00      1.00      1.00         1
#        21441       1.00      1.00      1.00         1
#        21442       1.00      1.00      1.00         1
#        21444       1.00      1.00      1.00         1
#        21445       1.00      1.00      1.00         1
#        21446       1.00      1.00      1.00         1
#        21449       1.00      1.00      1.00         1
#        21451       1.00      1.00      1.00         1
#        21452       1.00      1.00      1.00         1
#        21455       1.00      1.00      1.00         1
#        21459       1.00      1.00      1.00         1
#        21460       1.00      1.00      1.00         1
#        21462       1.00      1.00      1.00         1
#        21464       1.00      1.00      1.00         1
#        21468       1.00      1.00      1.00         1
#        21474       1.00      1.00      1.00         1
#        21475       1.00      1.00      1.00         1
#        21477       1.00      1.00      1.00         1
#        21479       1.00      1.00      1.00         1
#        21480       1.00      1.00      1.00         1
#        21481       1.00      1.00      1.00         1
#        21482       1.00      1.00      1.00         1
#        21484       1.00      1.00      1.00         1
#        21485       1.00      1.00      1.00         1
#        21487       1.00      1.00      1.00         1
#        21490       1.00      1.00      1.00         1
#        21491       1.00      1.00      1.00         1
#        21492       1.00      1.00      1.00         1
#        21493       1.00      1.00      1.00         1
#        21495       1.00      1.00      1.00         1
#        21500       1.00      1.00      1.00         1
#        21503       1.00      1.00      1.00         1
#        21511       1.00      1.00      1.00         1
#        21512       1.00      1.00      1.00         1
#        21513       1.00      1.00      1.00         1
#        21522       1.00      1.00      1.00         1
#        21523       1.00      1.00      1.00         1
#        21525       1.00      1.00      1.00         1
#        21526       1.00      1.00      1.00         1
#        21527       1.00      1.00      1.00         1
#        21528       1.00      1.00      1.00         1
#        21529       1.00      1.00      1.00         1
#        21530       1.00      1.00      1.00         1
#        21531       1.00      1.00      1.00         1
#        21532       1.00      1.00      1.00         1
#        21534       1.00      1.00      1.00         1
#        21535       1.00      1.00      1.00         1
#        21537       1.00      1.00      1.00         1
#        21546       1.00      1.00      1.00         1
#        21548       1.00      1.00      1.00         1
#        21549       1.00      1.00      1.00         1
#        21550       1.00      1.00      1.00         1
#        21551       1.00      1.00      1.00         1
#        21552       1.00      1.00      1.00         1
#        21555       1.00      1.00      1.00         1
#        21556       1.00      1.00      1.00         1
#        21557       1.00      1.00      1.00         1
#        21561       1.00      1.00      1.00         1
#        21562       1.00      1.00      1.00         1
#        21563       1.00      1.00      1.00         1
#        21566       1.00      1.00      1.00         1
#        21567       1.00      1.00      1.00         1
#        21568       1.00      1.00      1.00         1
#        21569       1.00      1.00      1.00         1
#        21571       1.00      1.00      1.00         1
#        21572       1.00      1.00      1.00         1
#        21573       1.00      1.00      1.00         1
#        21574       1.00      1.00      1.00         1
#        21583       1.00      1.00      1.00         1
#        21585       1.00      1.00      1.00         1
#        21586       1.00      1.00      1.00         1
#        21588       1.00      1.00      1.00         1
#        21592       1.00      1.00      1.00         1
#        21602       1.00      1.00      1.00         1
#        21603       1.00      1.00      1.00         1
#        21619       1.00      1.00      1.00         1
#        21630       1.00      1.00      1.00         1
#        21634       1.00      1.00      1.00         1
#        21637       1.00      1.00      1.00         1
#        21641       1.00      1.00      1.00         1
#        21644       1.00      1.00      1.00         1
#        21646       1.00      1.00      1.00         1
#        21647       1.00      1.00      1.00         1
#        21648       1.00      1.00      1.00         1
#        21650       1.00      1.00      1.00         1
#        21652       1.00      1.00      1.00         1
#        21653       1.00      1.00      1.00         1
#        21654       1.00      1.00      1.00         1
#        21656       1.00      1.00      1.00         1
#        21657       1.00      1.00      1.00         1
#        21666       1.00      1.00      1.00         1
#        21667       1.00      1.00      1.00         1
#        21671       1.00      1.00      1.00         1
#        21673       1.00      1.00      1.00         1
#        21676       1.00      1.00      1.00         1
#        21677       1.00      1.00      1.00         1
#        21686       1.00      1.00      1.00         1
#        21694       1.00      1.00      1.00         1
#        21697       1.00      1.00      1.00         1
#        21698       1.00      1.00      1.00         1
#        21699       1.00      1.00      1.00         1
#        21701       1.00      1.00      1.00         1
#        21702       1.00      1.00      1.00         1
#        21703       1.00      1.00      1.00         1
#        21705       1.00      1.00      1.00         1
#        21706       1.00      1.00      1.00         1
#        21708       1.00      1.00      1.00         1
#        21709       1.00      1.00      1.00         1
#        21712       1.00      1.00      1.00         1
#        21713       1.00      1.00      1.00         1
#        21715       1.00      1.00      1.00         1
#        21718       1.00      1.00      1.00         1
#        21719       1.00      1.00      1.00         1
#        21723       1.00      1.00      1.00         1
#        21724       1.00      1.00      1.00         1
#        21726       1.00      1.00      1.00         1
#        21728       1.00      1.00      1.00         1
#        21729       1.00      1.00      1.00         1
#        21732       1.00      1.00      1.00         1
#        21733       1.00      1.00      1.00         1
#        21734       1.00      1.00      1.00         1
#        21735       1.00      1.00      1.00         1
#        21736       1.00      1.00      1.00         1
#        21737       1.00      1.00      1.00         1
#        21738       1.00      1.00      1.00         1
#        21739       1.00      1.00      1.00         1
#        21740       1.00      1.00      1.00         1
#        21742       1.00      1.00      1.00         1
#        21743       1.00      1.00      1.00         1
#        21747       1.00      1.00      1.00         1
#        21748       1.00      1.00      1.00         1
#        21751       1.00      1.00      1.00         1
#        21753       1.00      1.00      1.00         1
#        21755       1.00      1.00      1.00         1
#        21756       1.00      1.00      1.00         1
#        21760       1.00      1.00      1.00         1
#        21762       1.00      1.00      1.00         1
#        21763       1.00      1.00      1.00         1
#        21764       1.00      1.00      1.00         1
#        21765       1.00      1.00      1.00         1
#        21768       1.00      1.00      1.00         1
#        21769       1.00      1.00      1.00         1
#        21770       1.00      1.00      1.00         1
#        21772       1.00      1.00      1.00         1
#        21773       1.00      1.00      1.00         1
#        21774       1.00      1.00      1.00         1
#        21778       1.00      1.00      1.00         1
#        21779       1.00      1.00      1.00         1
#        21782       1.00      1.00      1.00         1
#        21783       1.00      1.00      1.00         1
#        21784       1.00      1.00      1.00         1
#        21789       1.00      1.00      1.00         1
#        21791       1.00      1.00      1.00         1
#        21793       1.00      1.00      1.00         1
#        21795       1.00      1.00      1.00         1
#        21797       1.00      1.00      1.00         1
#        21800       1.00      1.00      1.00         1
#        21802       1.00      1.00      1.00         1
#        21803       1.00      1.00      1.00         1
#        21804       1.00      1.00      1.00         1
#        21805       1.00      1.00      1.00         1
#        21809       1.00      1.00      1.00         1
#        21811       1.00      1.00      1.00         1
#        21812       1.00      1.00      1.00         1
#        21813       1.00      1.00      1.00         1
#        21814       1.00      1.00      1.00         1
#        21815       1.00      1.00      1.00         1
#        21820       1.00      1.00      1.00         1
#        21821       1.00      1.00      1.00         1
#        21822       1.00      1.00      1.00         1
#        21823       1.00      1.00      1.00         1
#        21824       1.00      1.00      1.00         1
#        21828       1.00      1.00      1.00         1
#        21829       1.00      1.00      1.00         1
#        21830       1.00      1.00      1.00         1
#        21835       1.00      1.00      1.00         1
#        21841       1.00      1.00      1.00         1
#        21843       1.00      1.00      1.00         1
#        21857       1.00      1.00      1.00         1
#        21858       1.00      1.00      1.00         1
#        21859       1.00      1.00      1.00         1
#        21863       1.00      1.00      1.00         1
#        21865       1.00      1.00      1.00         1
#        21866       1.00      1.00      1.00         1
#        21867       1.00      1.00      1.00         1
#        21868       1.00      1.00      1.00         1
#        21874       1.00      1.00      1.00         1
#        21876       1.00      1.00      1.00         1
#        21881       1.00      1.00      1.00         1
#        21882       1.00      1.00      1.00         1
#        21889       1.00      1.00      1.00         1
#        21893       1.00      1.00      1.00         1
#        21895       1.00      1.00      1.00         1
#        21897       1.00      1.00      1.00         1
#        21898       1.00      1.00      1.00         1
#        21902       1.00      1.00      1.00         1
#        21907       1.00      1.00      1.00         1
#        21915       1.00      1.00      1.00         1
#        21922       1.00      1.00      1.00         1
#        21928       1.00      1.00      1.00         1
#        21933       1.00      1.00      1.00         1
#        21935       1.00      1.00      1.00         1
#        21936       1.00      1.00      1.00         1
#        21937       1.00      1.00      1.00         1
#        21940       1.00      1.00      1.00         1
#        21942       1.00      1.00      1.00         1
#        21944       1.00      1.00      1.00         1
#        21946       1.00      1.00      1.00         1
#        21947       1.00      1.00      1.00         1
#        21949       1.00      1.00      1.00         1
#        21950       1.00      1.00      1.00         1
#        21951       1.00      1.00      1.00         1
#        21953       1.00      1.00      1.00         2
#        21955       1.00      1.00      1.00         1
#        21958       1.00      1.00      1.00         1
#        21960       1.00      1.00      1.00         1
#        21961       1.00      1.00      1.00         1
#        21963       1.00      1.00      1.00         1
#        21965       1.00      1.00      1.00         1
#        21967       1.00      1.00      1.00         1
#        21970       1.00      1.00      1.00         1
#        21973       1.00      1.00      1.00         1
#        21975       1.00      1.00      1.00         1
#        21977       1.00      1.00      1.00         1
#        21978       1.00      1.00      1.00         1
#        21979       1.00      1.00      1.00         1
#        21981       1.00      1.00      1.00         1
#        21985       1.00      1.00      1.00         1
#        21988       1.00      1.00      1.00         1
#        21994       1.00      1.00      1.00         1
#        21996       1.00      1.00      1.00         1
#        21997       1.00      1.00      1.00         1
#        22007       1.00      1.00      1.00         1
#        22008       1.00      1.00      1.00         1
#        22017       1.00      1.00      1.00         1
#        22021       1.00      1.00      1.00         1
#        22026       1.00      1.00      1.00         1
#        22027       1.00      1.00      1.00         1
#        22028       1.00      1.00      1.00         1
#        22029       1.00      1.00      1.00         1
#        22036       1.00      1.00      1.00         1
#        22037       1.00      1.00      1.00         1
#        22038       1.00      1.00      1.00         1
#        22041       1.00      1.00      1.00         1
#        22042       1.00      1.00      1.00         1
#        22044       1.00      1.00      1.00         1
#
#     accuracy                           1.00     10003
#    macro avg       1.00      1.00      1.00     10003
# weighted avg       1.00      1.00      1.00     10003
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
string_test = ['jkw', 'yg', 'menang', 'bkn', 'wowo']
kalimat_awal = le_kata_sebelum.transform(string_test)

kalimat_awal = kalimat_awal[ :, np.newaxis]

kalimat_prediksi = clf.predict(kalimat_awal)

print(le_kata_kbbi.inverse_transform(kalimat_prediksi))
# Out:
# ['jokowi' 'yang' 'menang' 'bukan' 'prabowo']
